# %%
import sys
import os
import import_ipynb
import gdown

# %%
sys.path.append(os.path.abspath('.'))

# %%
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\reus\Desktop\Tenx\Cross-Country Solar Farm Analysis\src\notebooks\scripts

# %%
from main import SolarDataAnalyzer

# %%
analyzer = SolarDataAnalyzer('Data/benin-malanville.csv', 'benin')

# %%
missing_report = analyzer.initial_profiling()
# Out:
# ============================================================
# INITIAL DATA PROFILE - BENIN
# ============================================================
#
# Dataset Shape: (525600, 19)
# Date Range: 2021-08-09 00:01 to 2022-08-09 00:00
#
# MISSING VALUES REPORT
# ------------------------------------------------------------
#           Missing_Count  Percentage
# Comments         525600       100.0
#
# ⚠️  CRITICAL: 1 columns have >5% missing values
#           Missing_Count  Percentage
# Comments         525600       100.0
#
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      240.559452     167.187516     115.358961     236.589496
# std       331.131327     261.710501     158.691074     326.894859
# min       -12.900000      -7.800000     -12.600000       0.000000
# 25%        -2.000000      -0.500000      -2.100000       0.000000
# 50%         1.800000      -0.100000       1.600000       4.500000
# 75%       483.400000     314.200000     216.300000     463.700000
# max      1413.000000     952.300000     759.200000    1342.300000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      228.883576      28.179683      54.487969       2.121113
# std       316.536515       5.924297      28.073069       1.603466
# min         0.000000      11.000000       2.100000       0.000000
# 25%         0.000000      24.200000      28.800000       1.000000
# 50%         4.300000      28.000000      55.100000       1.900000
# 75%       447.900000      32.300000      80.100000       3.100000
# max      1342.300000      43.800000     100.000000      19.500000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        2.809195       0.473390     153.435172       8.582407
# std         2.029120       0.273395     102.332842       6.385864
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.300000       0.400000      59.000000       3.700000
# 50%         2.600000       0.500000     181.000000       8.600000
# 75%         4.100000       0.600000     235.100000      12.300000
# max        26.600000       4.200000     360.000000      99.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      994.197199       0.000923       0.001905      35.246026
# std         2.474993       0.030363       0.037115      14.807258
# min       985.000000       0.000000       0.000000       9.000000
# 25%       993.000000       0.000000       0.000000      24.200000
# 50%       994.000000       0.000000       0.000000      30.000000
# 75%       996.000000       0.000000       0.000000      46.900000
# max      1003.000000       1.000000       2.500000      81.000000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.471736       NaN
# std        12.348743       NaN
# min         8.100000       NaN
# 25%        23.600000       NaN
# 50%        28.900000       NaN
# 75%        41.500000       NaN
# max        72.500000       NaN

# %%
outliers = analyzer.detect_outliers()
# Out:
# ============================================================
# OUTLIER DETECTION (Z-score method, |Z| > 3)
# ============================================================
#
# GHI             :    89 outliers (0.02%)
# DNI             :     0 outliers (0.00%)
# DHI             :  3738 outliers (0.71%)
# ModA            :    27 outliers (0.01%)
# ModB            :    63 outliers (0.01%)
# WS              :  3109 outliers (0.59%)
# WSgust          :  3500 outliers (0.67%)

# %%
clean_df = analyzer.clean_data(strategy='median')
# Out:
# ============================================================
# DATA CLEANING
# ============================================================
#
# ✓ Corrected 258847 negative values in GHI
# ✓ Corrected 275987 negative values in DNI
# ✓ Corrected 259182 negative values in DHI
#
# ✓ Cleaned dataset shape: (525600, 19)

# %%
analyzer.time_series_analysis()

# %%
analyzer.cleaning_impact_analysis()
# Out:
# Cleaning Impact Statistics:
#                 ModA        ModB
# Cleaning
# 0         236.524253  228.816071
# 1         307.229278  301.972165
#
# ✓ ModA improvement after cleaning: 29.89%
# ✓ ModB improvement after cleaning: 31.97%

# %%
analyzer.wind_analysis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 analyzer.wind_analysis()
#
# File <string>:283, in wind_analysis(self)
#
# AttributeError: 'Axes' object has no attribute 'set_theta_zero_location'

# %%
analyzer.distribution_analysis()

# %%
analyzer.temperature_humidity_analysis()

# %%
analyzer.bubble_chart()

# %%
analyzer.generate_insights_report()
# Out:
# ======================================================================
# KEY INSIGHTS REPORT - BENIN
# ======================================================================
#
# 1. SOLAR POTENTIAL METRICS
# ----------------------------------------------------------------------
#    Average GHI: 241.96 W/m²
#    Peak GHI: 1413.00 W/m²
#    Average DNI: 167.44 W/m²
#    Average DHI: 116.99 W/m²
#    GHI Variability (Std Dev): 330.10 W/m²
#
# 2. ENVIRONMENTAL CONDITIONS
# ----------------------------------------------------------------------
#    Average Temperature: 28.18 °C
#    Average Humidity: 54.49 %
#    Average Wind Speed: 2.12 m/s
#    Average Pressure: 994.20 hPa
#
# 3. MODULE PERFORMANCE
# ----------------------------------------------------------------------
#    Average ModA: 236.59 W/m²
#    Average ModB: 228.88 W/m²
#    Average Module Temp A: 35.25 °C
#    Average Module Temp B: 32.47 °C
#
# 4. TEMPORAL PATTERNS
# ----------------------------------------------------------------------
#    Peak Solar Hour: 12:00
#    Peak Solar Month: 4
#
# 5. DATA QUALITY SCORE
# ----------------------------------------------------------------------
#    Data Completeness: 94.74%
#
# ======================================================================

# %%
analyzer.export_cleaned_data('Data/benin.csv')
# Out:
# ✓ Cleaned data exported to: Data/benin.csv
