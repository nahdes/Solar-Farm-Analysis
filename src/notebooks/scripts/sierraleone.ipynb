# %%
import sys
import os
import import_ipynb
import gdown

# %%
sys.path.append(os.path.abspath('.'))

# %%
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\reus\Desktop\Tenx\Cross-Country Solar Farm Analysis\src\notebooks\scripts

# %%
from main import SolarDataAnalyzer

# %%
analyzer = SolarDataAnalyzer('Data/sierraleone-bumbuna.csv', 'sierraleone')

# %%
missing_report = analyzer.initial_profiling()
# Out:
# ============================================================
# INITIAL DATA PROFILE - SIERRALEONE
# ============================================================
#
# Dataset Shape: (525600, 19)
# Date Range: 2021-10-30 00:01 to 2022-10-30 00:00
#
# MISSING VALUES REPORT
# ------------------------------------------------------------
#           Missing_Count  Percentage
# Comments         525600       100.0
#
# ⚠️  CRITICAL: 1 columns have >5% missing values
#           Missing_Count  Percentage
# Comments         525600       100.0
#
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       345.400000      29.400000      96.700000       2.000000
# max      1473.000000      39.900000     100.000000      19.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.691606       0.363823     133.044668       7.172220
# std         1.617053       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max        23.900000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.593091       NaN
# std        12.009161       NaN
# min        11.100000       NaN
# 25%        23.800000       NaN
# 50%        26.900000       NaN
# 75%        41.300000       NaN
# max        70.400000       NaN

# %%
outliers = analyzer.detect_outliers()
# Out:
# ============================================================
# OUTLIER DETECTION (Z-score method, |Z| > 3)
# ============================================================
#
# GHI             :  2477 outliers (0.47%)
# DNI             :  7586 outliers (1.44%)
# DHI             :  2986 outliers (0.57%)
# ModA            :  1604 outliers (0.31%)
# ModB            :  2041 outliers (0.39%)
# WS              :  3967 outliers (0.75%)
# WSgust          :  3665 outliers (0.70%)

# %%
clean_df = analyzer.clean_data(strategy='median')
# Out:
# ============================================================
# DATA CLEANING
# ============================================================
#
# ✓ Corrected 261135 negative values in GHI
# ✓ Corrected 266352 negative values in DNI
# ✓ Corrected 263128 negative values in DHI
#
# ✓ Cleaned dataset shape: (525600, 19)

# %%
analyzer.time_series_analysis()

# %%
analyzer.cleaning_impact_analysis()
# Out:
# Cleaning Impact Statistics:
#                 ModA        ModB
# Cleaning
# 0         206.578599  198.038150
# 1         273.309252  277.231102
#
# ✓ ModA improvement after cleaning: 32.30%
# ✓ ModB improvement after cleaning: 39.99%

# %%
analyzer.wind_analysis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 analyzer.wind_analysis()
#
# File <string>:283, in wind_analysis(self)
#
# AttributeError: 'Axes' object has no attribute 'set_theta_zero_location'

# %%
analyzer.distribution_analysis()

# %%
analyzer.temperature_humidity_analysis()

# %%
analyzer.bubble_chart()

# %%
analyzer.generate_insights_report()
# Out:
# ======================================================================
# KEY INSIGHTS REPORT - SIERRALEONE
# ======================================================================
#
# 1. SOLAR POTENTIAL METRICS
# ----------------------------------------------------------------------
#    Average GHI: 204.41 W/m²
#    Peak GHI: 1499.00 W/m²
#    Average DNI: 116.52 W/m²
#    Average DHI: 116.27 W/m²
#    GHI Variability (Std Dev): 296.79 W/m²
#
# 2. ENVIRONMENTAL CONDITIONS
# ----------------------------------------------------------------------
#    Average Temperature: 26.32 °C
#    Average Humidity: 79.45 %
#    Average Wind Speed: 1.15 m/s
#    Average Pressure: 999.88 hPa
#
# 3. MODULE PERFORMANCE
# ----------------------------------------------------------------------
#    Average ModA: 206.64 W/m²
#    Average ModB: 198.11 W/m²
#    Average Module Temp A: 32.50 °C
#    Average Module Temp B: 32.59 °C
#
# 4. TEMPORAL PATTERNS
# ----------------------------------------------------------------------
#    Peak Solar Hour: 12:00
#    Peak Solar Month: 4
#
# 5. DATA QUALITY SCORE
# ----------------------------------------------------------------------
#    Data Completeness: 94.74%
#
# ======================================================================

# %%
analyzer.export_cleaned_data('Data/sierraleone.csv')
# Out:
# ✓ Cleaned data exported to: Data/sierraleone.csv
