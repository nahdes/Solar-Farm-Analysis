# %%
import sys
import os

# %%
sys.path.append(os.path.abspath('.'))

# %%
from cross_country_analyzer import CrossCountryAnalyze
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from cross_country_analyzer import CrossCountryAnalyze
#
# ModuleNotFoundError: No module named 'cross_country_analyzer'
